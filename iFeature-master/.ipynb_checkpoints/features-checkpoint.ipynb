# %%
#AAC
import os

# %%
import pandas as pd
import numpy as np

p_AAC = pd.read_table('iFeature-master/pos_40_AAC.txt')
n_AAC = pd.read_table('iFeature-master/neg_40_AAC.txt')
p_AAC
# Out:
#                #         A         C         D         E         F         G  \
# 0         PLMD-2  0.000000  0.000000  0.024390  0.048780  0.073171  0.146341
# 1         PLMD-4  0.073171  0.024390  0.073171  0.000000  0.048780  0.146341
# 2         PLMD-7  0.073171  0.024390  0.048780  0.073171  0.000000  0.048780
# 3         PLMD-7  0.048780  0.000000  0.000000  0.121951  0.000000  0.048780
# 4         PLMD-8  0.024390  0.000000  0.024390  0.121951  0.000000  0.024390
# 5         PLMD-8  0.048780  0.048780  0.048780  0.024390  0.048780  0.048780
# 6         PLMD-9  0.048780  0.024390  0.097561  0.048780  0.024390  0.024390
# 7         PLMD-9  0.048780  0.048780  0.073171  0.146341  0.048780  0.048780
# 8         PLMD-9  0.000000  0.048780  0.073171  0.048780  0.073171  0.024390
# 9         PLMD-9  0.097561  0.024390  0.000000  0.073171  0.048780  0.048780
# 10        PLMD-9  0.073171  0.000000  0.048780  0.073171  0.073171  0.073171
# ...

# %%
#AAC圖
#大寫是Positive
#小寫是negative

import matplotlib.pyplot as plt
import seaborn as sns
#pAAC = p_AAC.iloc[:,1:]
#nAAC = n_AAC.iloc[:,1:]
pAAC = p_AAC
nAAC = n_AAC
pAAC['tag']=1
nAAC['tag']=0
temp = pd.concat([pAAC,nAAC],axis=0)

temp.boxplot(by='tag',showfliers=False,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025E5CB80358>,
# ...
#       dtype=object)

# %%
pos_AAINDEX = pd.read_table('iFeature-master/pos_40_AAINDEX.txt')

# %%
pos_AAINDEX
# Out:
#                #  SeqPos.1.ANDN920101  SeqPos.1.ARGP820101  \
# 0         PLMD-2                 4.37                 0.00
# 1         PLMD-4                 3.97                 0.07
# 2         PLMD-7                 4.35                 0.05
# 3         PLMD-7                 4.35                 0.05
# 4         PLMD-8                 4.36                 1.15
# 5         PLMD-8                 4.65                 1.07
# 6         PLMD-9                 4.44                 1.95
# 7         PLMD-9                 3.95                 2.22
# 8         PLMD-9                 3.95                 1.32
# 9         PLMD-9                 4.36                 1.15
# 10        PLMD-9                 4.38                 0.60
# 11       PLMD-13                 3.95                 2.22
# 12       PLMD-13                 4.63                 0.61
# 13       PLMD-17                 4.50                 0.05
# 14       PLMD-17                 4.37                 0.00
# ...

# %%
import tensorflow as tf
p = tf.constant(3.0, tf.float32)
with tf.Session():
    print(p.eval())
# Out:
# 3.0

# %%
p = tf.argmax(y_conv,1)
sess=tf.Session()
print(p.eval)
# Out:
# array([1., 3.], dtype=float32)
